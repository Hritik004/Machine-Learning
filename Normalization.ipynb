# %% [markdown]
# <a href="https://colab.research.google.com/github/Hritik004/Machine-Learning/blob/main/Normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/Social_Network_Ads.csv")

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
sns.kdeplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
color_dict={1:'red',2:'blue'}
sns.scatterplot(x=df['Age'],y=df['EstimatedSalary'],data=df,hue='Purchased',palette=color_dict)
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop('Purchased',axis=1),df['Purchased'],test_size=0.3,random_state=0)
x_train.shape
# Out:
# (280, 2)

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd # Make sure pandas is imported

scaler=MinMaxScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# Convert x_train_scaled and x_test_scaled to Pandas DataFrames
x_train_scaled = pd.DataFrame(x_train_scaled, columns=[['Age', 'EstimatedSalary']]) # Use a list of column names
x_test_scaled = pd.DataFrame(x_test_scaled, columns=[['Age', 'EstimatedSalary']]) # Use a list of column names

np.round(x_train.describe(), 1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.5              0.4
# std      0.2              0.3
# min      0.0              0.0
# 25%      0.3              0.2
# 50%      0.5              0.4
# 75%      0.7              0.5
# max      1.0              1.0

# %%
np.round(x_train_scaled.describe(), 1)
# Out:
#          Age EstimatedSalary
# count  280.0           280.0
# mean     0.5             0.4
# std      0.2             0.3
# min      0.0             0.0
# 25%      0.3             0.2
# 50%      0.5             0.4
# 75%      0.7             0.5
# max      1.0             1.0

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,5))
ax1.scatter(x_train['Age'],x_train['EstimatedSalary'])
ax1.set_title("Before scaling")
ax2.scatter(x_train_scaled['Age'],x_train_scaled['EstimatedSalary'],color='red')
ax2.set_title("After scaling")
plt.show  ()

# %%
sns.kdeplot(x_train['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(x_train_scaled['Age'],color='red')
# Out:
# <Axes: ylabel='Density'>
